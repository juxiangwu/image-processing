# %%
import numpy as np
import numpy.linalg
from scipy.ndimage import filters
# %matplotlib inline
import matplotlib.pyplot as plt
import imageio
import cv2
from scipy.ndimage import filters

# %%
img = imageio.imread('../datas/f3.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY).astype(np.float32)

# %%
sigma = 3.0
imx = np.zeros(gray.shape)
imx = gray + 0.4 * (gray - filters.gaussian_filter(gray, sigma))
imx = np.clip(imx, 0, 255)
imx = np.uint8(imx)

# %%
plt.imshow(imx,'gray')
