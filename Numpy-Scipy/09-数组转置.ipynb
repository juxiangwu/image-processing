# %% [markdown]
# # 数组转置

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
bgr = cv2.imread('../datas/f3.jpg')

# %%
plt.imshow(bgr)
plt.title('BGR')
# Out:
# Text(0.5,1,'BGR')
