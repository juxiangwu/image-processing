# %% [markdown]
# # scikit-image API-Color

# %%
from skimage import data
import skimage.color as color
import numpy as np
# %matplotlib  inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.转换颜色空间
#
# scikit-image支持的颜色空间有：‘RGB’, ‘HSV’, ‘RGB CIE’, ‘XYZ’, ‘YUV’, ‘YIQ’, ‘YPbPr’, ‘YCbCr’, ‘YDbDr’。可以使用skimage.color.convert_colorspace(arr,fromspace,tospace)方法

# %%
img = data.astronaut()
img_hsv = color.convert_colorspace(img,'RGB','HSV')
plt.subplot(121)
plt.imshow(img)
plt.title('RGB')
plt.subplot(122)
plt.imshow(img_hsv)
plt.title('RGB->HSV')
# Out:
# Text(0.5,1,'RGB->HSV')

# %% [markdown]
# ## 2.猜测图像的维度

# %%
dims = color.guess_spatial_dimensions(img)
print('dims:',dims)
# Out:
# dims: None

# %% [markdown]
# ## 3.更加方便的转换函数

# %% [markdown]
# ### 3.1RGB与HSV相互转换

# %%
img_hsv = color.rgb2hsv(img)
rgb = color.hsv2rgb(img_hsv)
plt.subplot(131)
plt.imshow(img)
plt.title('RGB')
plt.subplot(132)
plt.imshow(img_hsv)
plt.title('RGB->HSV')
plt.subplot(133)
plt.imshow(rgb)
plt.title('HSV->RGB')
# Out:
# Text(0.5,1,'HSV->RGB')

# %% [markdown]
# ### 3.2 RGB与XYZ相互转换

# %%
img_xyz = color.rgb2xyz(img)
rgb = color.xyz2rgb(img_xyz)
plt.subplot(131)
plt.imshow(img)
plt.title('RGB')
plt.subplot(132)
plt.imshow(np.uint8(img_xyz * 255))
# plt.imshow(img_xyz)
plt.title('RGB->XYZ')
plt.subplot(133)
plt.imshow(rgb)
plt.title('XYZ->RGB')
# Out:
# Text(0.5,1,'XYZ->RGB')

# %% [markdown]
# ### 3.3RGB与RGB CIE相互转换

# %%
img_rgbcie = color.rgb2rgbcie(img)
rgb = color.rgbcie2rgb(img_rgbcie)
plt.subplot(131)
plt.imshow(img)
plt.title('RGB')
plt.subplot(132)
plt.imshow(np.uint8(np.abs(img_rgbcie * 255)))
# plt.imshow(img_rgbcie)
plt.title('RGB->RGB CIE')
plt.subplot(133)
plt.imshow(np.uint8(np.abs(rgb * 255)))
plt.title('RGB CIE->RGB')
# Out:
# Text(0.5,1,'RGB CIE->RGB')

# %% [markdown]
# ### 3.4RGB转换灰度图像
#
# 使用转换公式：Y = 0.2125 R + 0.7154 G + 0.0721 B

# %%
img_gray = color.rgb2grey(img)
rgb = color.rgbcie2rgb(img_rgbcie)
plt.subplot(121)
plt.imshow(img)
plt.title('RGB')
plt.subplot(122)
# plt.imshow(np.uint8(img_rgbcie * 255))
plt.imshow(img_gray,'gray')
plt.title('RGB->Grey')
# Out:
# Text(0.5,1,'RGB->Grey')

# %%
img_gray = color.rgb2gray(img)
rgb = color.rgbcie2rgb(img_rgbcie)
plt.subplot(121)
plt.imshow(img)
plt.title('RGB')
plt.subplot(122)
# plt.imshow(np.uint8(img_rgbcie * 255))
plt.imshow(img_gray,'gray')
plt.title('RGB->Gray')
# Out:
# Text(0.5,1,'RGB->Gray')

# %% [markdown]
# ### 3.5XYZ与LAB相互转换

# %%
img_xyz = color.rgb2xyz(img)
img_lab = color.xyz2lab(img_xyz)
img_xyz = color.lab2xyz(img_lab)
plt.subplot(131)
plt.imshow(np.uint8(np.abs((img_xyz * 255))))
plt.title('XYZ')
plt.subplot(132)
# plt.imshow(np.uint8(img_rgbcie * 255))
plt.imshow(np.uint8(np.abs((img_lab))))
plt.title('XYZ->LAB')
plt.subplot(133)
plt.imshow(np.uint8(np.abs((img_xyz * 255))))
plt.title('LAB->XYZ')
# Out:
# Text(0.5,1,'LAB->XYZ')

# %% [markdown]
# ### 3.6RGB与LAB相互转换

# %%
img_lab = color.rgb2lab(img)
img_rgb = color.lab2rgb(img_lab)
plt.subplot(131)
plt.imshow(img)
plt.title('RGB')
plt.subplot(132)
plt.imshow(np.uint8(np.abs((img_lab))))
plt.title('RGB->LAB')
plt.subplot(133)
plt.imshow(img_rgb)
plt.title('LAB->RGB')
# Out:
# Text(0.5,1,'LAB->RGB')

# %% [markdown]
# ### 3.7RGB与HED相互转换
#
# Haematoxylin-Eosin-DAB（HED）

# %%
ihc = data.immunohistochemistry()
ihc_hed = color.rgb2hed(ihc)
img_rgb = color.hed2rgb(ihc_hed)
plt.subplot(131)
plt.imshow(ihc)
plt.title('RGB')
plt.subplot(132)
plt.imshow(np.uint8(np.abs(ihc_hed * 255)))
plt.title('RGB->HED')
plt.subplot(133)
plt.imshow(img_rgb)
plt.title('HED->RGB')
# Out:
# Text(0.5,1,'HED->RGB')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     330                 pass
#     331             else:
# --> 332                 return printer(obj)
#     333             # Finally look for special method names
#     334             method = get_real_method(obj, self.print_method)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     235
#     236     if 'png' in formats:
# --> 237         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     238     if 'retina' in formats or 'png2x' in formats:
#     239         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %% [markdown]
# ### 3.8LAB与LCH相互转换

# %%
img_lab = color.rgb2lab(img)
plt.subplot(131)
plt.imshow(np.uint8(np.abs((img_lab))))
plt.title('LAB')

img_lch = color.lab2lch(img_lab)
plt.subplot(132)
plt.imshow(np.uint8(np.abs((img_lch))))
plt.title('LAB->LCH')

img_lab = color.lch2lab(img_lch)
plt.subplot(133)
plt.imshow(np.uint8(np.abs((img_lab))))
plt.title('LCH->LAB')
# Out:
# Text(0.5,1,'LCH->LAB')

# %% [markdown]
# ### 3.8RGB与YUV相互转换

# %%
img_yuv = color.rgb2yuv(img)
plt.subplot(131)
plt.imshow(img)
plt.title('RGB')
plt.subplot(132)
plt.imshow(np.uint8(np.abs((img_yuv * 255))))
plt.title('RGB->YUV')
img_rgb = color.yuv2rgb(img_yuv)
plt.subplot(133)
plt.imshow(np.uint8(np.abs((img_rgb * 255))))
plt.title('YUV->RGB')
# Out:
# Text(0.5,1,'YUV->RGB')

# %% [markdown]
# ### 3.9RGB与YIQ相互转换

# %%
img_yiq = color.rgb2yiq(img)
print(img_yiq.shape,img_yiq.dtype)
plt.subplot(131)
plt.imshow(img)
plt.title('RGB')
plt.subplot(132)
plt.imshow(np.uint8(np.abs(img_yiq*255)))
plt.title('RGB->YIQ')
img_rgb = color.yiq2rgb(img_yiq)
plt.subplot(133)
plt.imshow(np.uint8(np.abs(img_rgb*255)))
plt.title('YIQ->RGB')
# Out:
# (512, 512, 3) float64
# Text(0.5,1,'YIQ->RGB')

# %% [markdown]
# ### 3.10RGB与YPBPR相互转换

# %%
img_ypbpr = color.rgb2ypbpr(img)
print(img_yiq.shape,img_yiq.dtype)
plt.subplot(131)
plt.imshow(img)
plt.title('RGB')
plt.subplot(132)
plt.imshow(np.uint8(np.abs(img_ypbpr*255)))
plt.title('RGB->YPBPR')
img_rgb = color.ypbpr2rgb(img_ypbpr)
plt.subplot(133)
plt.imshow(np.uint8(np.abs(img_rgb*255)))
plt.title('YPBPR->RGB')
# Out:
# (512, 512, 3) float64
# Text(0.5,1,'YPBPR->RGB')

# %% [markdown]
# ### 3.11 RGB与YCbCr相互转换

# %%
img_ycbcr = color.rgb2ycbcr(img)
plt.subplot(131)
plt.imshow(img)
plt.title('RGB')
plt.subplot(132)
plt.imshow(np.uint8(np.abs(img_ycbcr)))
plt.title('RGB->YCbCr')
img_rgb = color.ycbcr2rgb(img_ycbcr)
plt.subplot(133)
plt.imshow(np.uint8(np.abs(img_rgb* 255)))
plt.title('YCbCr->RGB')
# Out:
# Text(0.5,1,'YCbCr->RGB')

# %% [markdown]
# ### 3.12RGB与YDBDR相互转换

# %%
img_ydbdr = color.rgb2ydbdr(img)
plt.subplot(131)
plt.imshow(img)
plt.title('RGB')
plt.subplot(132)
plt.imshow(np.uint8(np.abs(img_ydbdr * 255)))
plt.title('RGB->YDbDr')
img_rgb = color.ydbdr2rgb(img_ydbdr)
plt.subplot(133)
plt.imshow(np.uint8(np.abs(img_rgb * 255)))
plt.title('YDbDr->RGB')
# Out:
# Text(0.5,1,'YDbDr->RGB')
