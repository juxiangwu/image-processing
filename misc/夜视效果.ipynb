# %%
#coding:utf-8
# %matplotlib inline
import cv2
import numpy as np
import matplotlib.pyplot as plt
'''
夜视效果
'''


src = cv2.imread('datas/animal.jpg')
src = cv2.cvtColor(src,cv2.COLOR_BGR2RGB)
channels = cv2.split(src)
# 降低R通道值，增加G通道值
channels[0] //= 2

dst = cv2.merge(channels)

plt.imshow(src)

# %%
plt.imshow(cv2.cvtColor(dst,cv2.COLOR_BGR2RGB))
