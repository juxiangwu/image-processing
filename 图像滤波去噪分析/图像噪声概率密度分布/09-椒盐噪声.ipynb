# %% [markdown]
# # 椒盐噪声

# %%
#coding:utf-8
# %matplotlib inline
import numpy as np
import scipy
from scipy.special import comb
import matplotlib.pyplot as plt
import cv2
from scipy import stats
import pandas as pd
from pandas import DataFrame

# %%
src = cv2.cvtColor(cv2.imread('../datas/f2.jpg'),cv2.COLOR_BGR2RGB)

# %%
def noise_pepper(img,a):
    m,n = img.shape[0],img.shape[1]
    R = np.random.randn(m,n)
    dst = np.zeros(img.shape,dtype=np.float64)
    rgb = np.float64(img)
    df_R = DataFrame(R)
    idx = df_R <= a
    dst[idx] = rgb[idx]
    return dst

# %%
noise = noise_pepper(src,0.01)

# %%
noise_uint = cv2.convertScaleAbs(noise)

# %%
plt.imshow(src)

# %%
plt.imshow(cv2.convertScaleAbs(noise))
