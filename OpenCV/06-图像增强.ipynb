# %% [markdown]
# # 图像增强

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
src = cv2.imread('../datas/f4.jpg')
rgb = cv2.cvtColor(src,cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(src,cv2.COLOR_BGR2GRAY)

# %%
channels = cv2.split(rgb)

# %% [markdown]
# ## 1.直方图均衡化

# %%
gr = cv2.equalizeHist(channels[0])
gg = cv2.equalizeHist(channels[1])
gb = cv2.equalizeHist(channels[2])
dst_histeq = cv2.merge([gr,gg,gb])

# %%
plt.subplot(121)
plt.imshow(rgb)
plt.title('SRC')
plt.subplot(122)
plt.imshow(dst_histeq)
plt.title('Histogram Equation')
# Out:
# Text(0.5,1,'Histogram Equation')

# %% [markdown]
# ## 2.对比度

# %%
alpha = -1
beta = 60
# rgb_f = rgb.astype(np.float64)
dst_contrast = alpha * rgb_f + beta
# dst_contrast[dst_contrast < 0] = 0
dst_contrast = np.abs(dst_contrast)
# dst_contrast[dst_contrast < 0] = 0
dst_contrast[dst_contrast > 255] = 255
dst_contrast = dst_contrast.astype(np.uint8)

# %%
plt.subplot(121)
plt.imshow(rgb)
plt.title('SRC')
plt.subplot(122)
plt.imshow(dst_contrast)
plt.title('Contrast')
# Out:
# Text(0.5,1,'Contrast')

# %% [markdown]
# ## 3.亮度

# %%
alpha = 1
rgb_f = rgb.astype(np.float64)
dst_brightness = alpha * rgb_f + beta
dst_brightness[dst_brightness > 255] = 255
dst_brightness = dst_brightness.astype(np.uint8)

# %%
plt.subplot(121)
plt.imshow(rgb)
plt.title('SRC')
plt.subplot(122)
plt.imshow(dst_brightness)
plt.title('Brightness')
# Out:
# Text(0.5,1,'Brightness')

# %% [markdown]
# ## 4.亮度对比度

# %%
alpha = 1.5
beta = -80
dst_brightness = alpha * rgb_f + beta
# dst_brightness[dst_brightness < 0 ] = 0
dst_contrast = np.abs(dst_contrast)
dst_brightness[dst_brightness > 255] = 255
dst_brightness = dst_brightness.astype(np.uint8)

# %%
plt.subplot(121)
plt.imshow(rgb)
plt.title('SRC')
plt.subplot(122)
plt.imshow(dst_brightness)
plt.title('Contrast & Brightness')
# Out:
# Text(0.5,1,'Contrast & Brightness')
