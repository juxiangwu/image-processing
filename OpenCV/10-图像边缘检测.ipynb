# %% [markdown]
# # 图像边缘检测

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
src = cv2.imread('../datas/f4.jpg')
rgb = cv2.cvtColor(src,cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(src,cv2.COLOR_BGR2GRAY)
rgb_f = rgb.astype(np.float32)

# %% [markdown]
# ## 1.Sobel算子

# %%
dst_sobel = cv2.Sobel(rgb,-1,0,1)

# %%
plt.imshow(dst_sobel)
plt.title('Sobel Edge Detect')
# Out:
# Text(0.5,1,'Sobel Edge Detect')

# %% [markdown]
# ## 2.Canny算子

# %%
dst_canny = cv2.Canny(gray,80,180)

# %%
plt.imshow(dst_canny,'gray')
plt.title('Canny')
# Out:
# Text(0.5,1,'Canny')

# %% [markdown]
# ## 3.Laplacian算子

# %%
dst_laplacian = cv2.Laplacian(rgb,-1)

# %%
plt.imshow(dst_laplacian)
plt.title('Laplacian')
# Out:
# Text(0.5,1,'Laplacian')

# %% [markdown]
# ## 4.Scharr算子

# %%
dst_scharr = cv2.Scharr(rgb,-1,0,1)

# %%
plt.imshow(dst_laplacian)
plt.title('Scharr')
# Out:
# Text(0.5,1,'Scharr')
